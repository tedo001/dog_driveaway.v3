# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Qlg2RjESX5PZL43LK0fD")
project = rf.workspace("dog-emotion-zaveh").project("dog-emotion-ovhny")
version = project.version(2)
dataset = version.download("yolov8")
